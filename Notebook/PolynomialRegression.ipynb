# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
np.random.rand(10,1)
# Out:
# array([[0.5116109 ],
#        [0.38230058],
#        [0.68248964],
#        [0.961981  ],
#        [0.06264232],
#        [0.90232183],
#        [0.3510942 ],
#        [0.36466722],
#        [0.1984573 ],
#        [0.74670028]])

# %%
X = 6 * np.random.rand(100, 1) - 3
y = 0.5 * X**2 + 1.5*X + 2 + np.random.randn(100, 1)

# %%
print(X)
# Out:
# [[ 1.46317655]
#  [-2.34991819]
#  [ 1.42367741]
#  [ 2.48630674]
#  [ 1.70394612]
#  [ 0.4921344 ]
#  [ 2.77577651]
#  [ 0.05043544]
#  [ 2.11819565]
#  [ 1.95870529]
#  [-0.45531355]
#  [ 0.90679633]
#  [-2.03890682]
#  [ 0.0878759 ]
#  [-1.93303018]
#  [ 2.202276  ]
#  [ 2.02989464]
#  [ 0.22420824]
#  [-1.9790387 ]
#  [-1.5472228 ]
#  [-1.00918172]
#  [ 1.268563  ]
#  [-0.23437203]
#  [ 0.12381562]
#  [-0.84741718]
#  [ 1.49672352]
#  [-1.38095846]
#  [-1.08870403]
#  [ 1.49376663]
#  [-0.75906158]
#  [ 0.00824694]
#  [ 0.87863168]
#  [ 1.68453355]
#  [-0.06350185]
#  [ 1.26995795]
#  [-1.21963317]
#  [ 0.23454521]
#  [ 0.74039136]
#  [-2.84398746]
#  [-1.82011012]
#  [-0.07375098]
#  [-1.43509767]
#  [ 2.68790293]
#  [ 2.25524613]
#  [-1.05285051]
#  [-1.59180147]
#  [-2.60012329]
#  [ 2.39310694]
#  [ 0.56307637]
#  [ 1.87048834]
#  [ 1.77579326]
#  [-0.9921655 ]
#  [-0.40911764]
#  [-0.06809281]
#  [-2.14649916]
#  [ 2.38519973]
#  [-2.57173308]
#  [ 2.36667031]
#  [ 0.67206112]
#  [ 2.0008882 ]
#  [-0.16813791]
#  [-2.23548518]
#  [ 1.40010335]
#  [ 2.1684628 ]
#  [ 0.70219354]
#  [ 0.82304469]
#  [ 2.46406105]
#  [-1.74302999]
#  [-0.40666514]
#  [-0.74092442]
#  [-2.93138542]
#  [-0.59220628]
#  [-1.35164576]
#  [-1.9284255 ]
#  [ 0.31160524]
#  [-2.80540793]
#  [-0.69908972]
#  [-0.84227182]
#  [ 0.88132698]
#  [ 1.75483999]
#  [-2.84941926]
#  [-0.6419804 ]
#  [-0.40003279]
#  [ 0.15878834]
#  [-2.32599033]
#  [-1.18560406]
#  [-1.4405337 ]
#  [ 2.04667665]
#  [ 1.93684615]
#  [ 1.92770361]
#  [ 2.41192611]
#  [-0.97898011]
#  [-1.64815779]
#  [ 0.33024892]
#  [ 1.69421281]
#  [ 1.92876064]
#  [-0.33440311]
#  [ 2.15518661]
#  [-2.55959266]
#  [-1.04915851]]

# %%
y
# Out:
# array([[ 5.22153963],
#        [ 1.03314569],
#        [ 4.72377274],
#        [ 9.54433066],
#        [ 5.47397901],
#        [ 4.36416074],
#        [ 8.02371886],
#        [ 4.31490521],
#        [ 7.79212731],
#        [ 6.7663414 ],
#        [ 1.80627277],
#        [ 5.23719754],
#        [ 0.17017711],
#        [ 1.82034941],
#        [ 1.71224312],
#        [ 8.32076751],
#        [ 8.94041714],
#        [ 3.57610282],
#        [ 1.75200553],
#        [ 2.31711933],
#        [ 0.65164278],
#        [ 3.17129637],
#        [ 0.83532432],
#        [ 1.54072386],
#        [ 0.93491896],
#        [ 5.92999802],
#        [-0.15168923],
#        [ 1.22876106],
#        [ 3.98882822],
#        [ 1.01501281],
#        [ 3.46979295],
#        [ 3.51548054],
#        [ 5.81616215],
#        [ 1.96681978],
#        [ 5.0807645 ],
#        [ 0.09218751],
#        [ 3.27801955],
#        [ 2.692465  ],
#        [-0.0821148 ],
#        [ 0.7695349 ],
#        [ 2.93232642],
#        [ 0.74173203],
#        [ 9.03263531],
#        [ 6.93715836],
#        [ 0.33255146],
#        [ 1.37443155],
#        [ 2.58379179],
#        [ 8.93871126],
#        [ 2.67925518],
#        [ 4.22942736],
#        [ 6.12720997],
#        [ 1.99374847],
#        [ 2.99091557],
#        [ 3.67049434],
#        [ 1.46145881],
#        [ 6.54162415],
#        [ 1.74088286],
#        [ 7.72753345],
#        [ 4.55054667],
#        [ 4.52691055],
#        [ 2.94187443],
#        [-0.74676996],
#        [ 6.55254883],
#        [ 7.26082591],
#        [ 3.09213591],
#        [ 2.04977302],
#        [ 8.84652264],
#        [ 1.14914279],
#        [ 1.38174563],
#        [-0.29141042],
#        [ 1.83243785],
#        [ 2.27148941],
#        [ 1.4430076 ],
#        [-0.80592696],
#        [ 3.67358811],
#        [ 1.70279964],
#        [-0.61525471],
#        [ 0.98329995],
#        [ 3.46659404],
#        [ 6.36672686],
#        [ 1.3692917 ],
#        [ 1.02857934],
#        [ 1.72897536],
#        [ 3.41564194],
#        [ 2.39769083],
#        [ 1.16904942],
#        [-1.48018312],
#        [ 5.26143562],
#        [ 6.12997734],
#        [ 7.73014408],
#        [10.30096957],
#        [ 1.36632475],
#        [ 1.29932189],
#        [ 2.55817658],
#        [ 6.63069961],
#        [ 5.9652071 ],
#        [ 2.46888531],
#        [ 9.11418464],
#        [ 1.42634967],
#        [ 1.03687747]])

# %%
X.shape, y.shape
# Out:
# ((100, 1), (100, 1))

# %%
# quadratic equation used - y = 0.5 * X**2 + 1.5*X + 2 + outliers
plt.scatter(X, y, color = 'g')
plt.xlabel('X dataset')
plt.ylabel('y dataset')
plt.show()

# %%
X
# Out:
# array([[ 1.46317655],
#        [-2.34991819],
#        [ 1.42367741],
#        [ 2.48630674],
#        [ 1.70394612],
#        [ 0.4921344 ],
#        [ 2.77577651],
#        [ 0.05043544],
#        [ 2.11819565],
#        [ 1.95870529],
#        [-0.45531355],
#        [ 0.90679633],
#        [-2.03890682],
#        [ 0.0878759 ],
#        [-1.93303018],
#        [ 2.202276  ],
#        [ 2.02989464],
#        [ 0.22420824],
#        [-1.9790387 ],
#        [-1.5472228 ],
#        [-1.00918172],
#        [ 1.268563  ],
#        [-0.23437203],
#        [ 0.12381562],
#        [-0.84741718],
#        [ 1.49672352],
#        [-1.38095846],
#        [-1.08870403],
#        [ 1.49376663],
#        [-0.75906158],
#        [ 0.00824694],
#        [ 0.87863168],
#        [ 1.68453355],
#        [-0.06350185],
#        [ 1.26995795],
#        [-1.21963317],
#        [ 0.23454521],
#        [ 0.74039136],
#        [-2.84398746],
#        [-1.82011012],
#        [-0.07375098],
#        [-1.43509767],
#        [ 2.68790293],
#        [ 2.25524613],
#        [-1.05285051],
#        [-1.59180147],
#        [-2.60012329],
#        [ 2.39310694],
#        [ 0.56307637],
#        [ 1.87048834],
#        [ 1.77579326],
#        [-0.9921655 ],
#        [-0.40911764],
#        [-0.06809281],
#        [-2.14649916],
#        [ 2.38519973],
#        [-2.57173308],
#        [ 2.36667031],
#        [ 0.67206112],
#        [ 2.0008882 ],
#        [-0.16813791],
#        [-2.23548518],
#        [ 1.40010335],
#        [ 2.1684628 ],
#        [ 0.70219354],
#        [ 0.82304469],
#        [ 2.46406105],
#        [-1.74302999],
#        [-0.40666514],
#        [-0.74092442],
#        [-2.93138542],
#        [-0.59220628],
#        [-1.35164576],
#        [-1.9284255 ],
#        [ 0.31160524],
#        [-2.80540793],
#        [-0.69908972],
#        [-0.84227182],
#        [ 0.88132698],
#        [ 1.75483999],
#        [-2.84941926],
#        [-0.6419804 ],
#        [-0.40003279],
#        [ 0.15878834],
#        [-2.32599033],
#        [-1.18560406],
#        [-1.4405337 ],
#        [ 2.04667665],
#        [ 1.93684615],
#        [ 1.92770361],
#        [ 2.41192611],
#        [-0.97898011],
#        [-1.64815779],
#        [ 0.33024892],
#        [ 1.69421281],
#        [ 1.92876064],
#        [-0.33440311],
#        [ 2.15518661],
#        [-2.55959266],
#        [-1.04915851]])

# %%
y
# Out:
# array([[ 5.22153963],
#        [ 1.03314569],
#        [ 4.72377274],
#        [ 9.54433066],
#        [ 5.47397901],
#        [ 4.36416074],
#        [ 8.02371886],
#        [ 4.31490521],
#        [ 7.79212731],
#        [ 6.7663414 ],
#        [ 1.80627277],
#        [ 5.23719754],
#        [ 0.17017711],
#        [ 1.82034941],
#        [ 1.71224312],
#        [ 8.32076751],
#        [ 8.94041714],
#        [ 3.57610282],
#        [ 1.75200553],
#        [ 2.31711933],
#        [ 0.65164278],
#        [ 3.17129637],
#        [ 0.83532432],
#        [ 1.54072386],
#        [ 0.93491896],
#        [ 5.92999802],
#        [-0.15168923],
#        [ 1.22876106],
#        [ 3.98882822],
#        [ 1.01501281],
#        [ 3.46979295],
#        [ 3.51548054],
#        [ 5.81616215],
#        [ 1.96681978],
#        [ 5.0807645 ],
#        [ 0.09218751],
#        [ 3.27801955],
#        [ 2.692465  ],
#        [-0.0821148 ],
#        [ 0.7695349 ],
#        [ 2.93232642],
#        [ 0.74173203],
#        [ 9.03263531],
#        [ 6.93715836],
#        [ 0.33255146],
#        [ 1.37443155],
#        [ 2.58379179],
#        [ 8.93871126],
#        [ 2.67925518],
#        [ 4.22942736],
#        [ 6.12720997],
#        [ 1.99374847],
#        [ 2.99091557],
#        [ 3.67049434],
#        [ 1.46145881],
#        [ 6.54162415],
#        [ 1.74088286],
#        [ 7.72753345],
#        [ 4.55054667],
#        [ 4.52691055],
#        [ 2.94187443],
#        [-0.74676996],
#        [ 6.55254883],
#        [ 7.26082591],
#        [ 3.09213591],
#        [ 2.04977302],
#        [ 8.84652264],
#        [ 1.14914279],
#        [ 1.38174563],
#        [-0.29141042],
#        [ 1.83243785],
#        [ 2.27148941],
#        [ 1.4430076 ],
#        [-0.80592696],
#        [ 3.67358811],
#        [ 1.70279964],
#        [-0.61525471],
#        [ 0.98329995],
#        [ 3.46659404],
#        [ 6.36672686],
#        [ 1.3692917 ],
#        [ 1.02857934],
#        [ 1.72897536],
#        [ 3.41564194],
#        [ 2.39769083],
#        [ 1.16904942],
#        [-1.48018312],
#        [ 5.26143562],
#        [ 6.12997734],
#        [ 7.73014408],
#        [10.30096957],
#        [ 1.36632475],
#        [ 1.29932189],
#        [ 2.55817658],
#        [ 6.63069961],
#        [ 5.9652071 ],
#        [ 2.46888531],
#        [ 9.11418464],
#        [ 1.42634967],
#        [ 1.03687747]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
## Simple Linear Regression
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()

# %%
lin_reg
# Out:
# LinearRegression()

# %%
lin_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test, lin_reg.predict(X_test))
print('R2 score for Linear Regression:', score)
# Out:
# R2 score for Linear Regression: 0.7459946891969798

# %%
## Visualize this model
plt.plot(X_train, lin_reg.predict(X_train), color = 'r')
plt.scatter(X_train, y_train, color = 'g')
plt.xlabel('X dataset')
plt.ylabel('y dataset')
plt.show()

# %%
## Visualize this model
plt.plot(X_test, lin_reg.predict(X_test), color = 'r')
plt.scatter(X_test, y_test, color = 'g')
plt.xlabel('X dataset')
plt.ylabel('y dataset')
# Out:
# Text(0, 0.5, 'y dataset')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
## Applying Polynomial Transformation
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree = 5)
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

# %%
X_train_poly
# Out:
# array([[ 1.00000000e+00,  9.06796325e-01,  8.22279575e-01,
#          7.45640097e-01,  6.76143700e-01,  6.13124622e-01],
#        [ 1.00000000e+00,  2.39310694e+00,  5.72696082e+00,
#          1.37052297e+01,  3.27980802e+01,  7.84893133e+01],
#        [ 1.00000000e+00, -1.18560406e+00,  1.40565700e+00,
#         -1.66655265e+00,  1.97587159e+00, -2.34260139e+00],
#        [ 1.00000000e+00,  1.49376663e+00,  2.23133874e+00,
#          3.33309934e+00,  4.97887257e+00,  7.43727369e+00],
#        [ 1.00000000e+00,  3.30248922e-01,  1.09064351e-01,
#          3.60183843e-02,  1.18950326e-02,  3.92832170e-03],
#        [ 1.00000000e+00,  4.92134398e-01,  2.42196266e-01,
#          1.19193114e-01,  5.86590312e-02,  2.88681270e-02],
#        [ 1.00000000e+00,  2.46406105e+00,  6.07159686e+00,
#          1.49607853e+01,  3.68642884e+01,  9.08358572e+01],
#        [ 1.00000000e+00,  8.23044694e-01,  6.77402569e-01,
#          5.57532590e-01,  4.58874240e-01,  3.77674009e-01],
#        [ 1.00000000e+00, -1.21963317e+00,  1.48750507e+00,
#         -1.81421052e+00,  2.21267133e+00, -2.69864735e+00],
#        [ 1.00000000e+00,  2.02989464e+00,  4.12047226e+00,
#          8.36412457e+00,  1.69782917e+01,  3.44641433e+01],
#        [ 1.00000000e+00,  1.87048834e+00,  3.49872662e+00,
#          6.54432733e+00,  1.22410879e+01,  2.28968122e+01],
#        [ 1.00000000e+00,  1.26995795e+00,  1.61279319e+00,
#          2.04817953e+00,  2.60110187e+00,  3.30328999e+00],
#        [ 1.00000000e+00,  5.04354421e-02,  2.54373382e-03,
#          1.28294340e-04,  6.47058175e-06,  3.26346651e-07],
#        [ 1.00000000e+00,  1.92876064e+00,  3.72011760e+00,
#          7.17521639e+00,  1.38392749e+01,  2.66926487e+01],
#        [ 1.00000000e+00, -1.08870403e+00,  1.18527645e+00,
#         -1.29041525e+00,  1.40488027e+00, -1.52949881e+00],
#        [ 1.00000000e+00, -1.54722280e+00,  2.39389839e+00,
#         -2.98930529e+00,  4.30619502e+00, -6.20321907e+00],
#        [ 1.00000000e+00, -4.00032791e-01,  1.60026234e-01,
#         -6.40157411e-02,  2.56083956e-02, -1.02441980e-02],
#        [ 1.00000000e+00, -1.00918172e+00,  1.01844774e+00,
#         -1.02779884e+00,  1.03723580e+00, -1.04675940e+00],
#        [ 1.00000000e+00, -1.68137915e-01,  2.82703584e-02,
#         -4.75331912e-03,  7.99213165e-04, -1.34378035e-04],
#        [ 1.00000000e+00, -5.92206281e-01,  3.50708279e-01,
#         -2.07691645e-01,  1.22996297e-01, -7.28391794e-02],
#        [ 1.00000000e+00, -1.93303018e+00,  3.73660569e+00,
#         -7.22297160e+00,  1.39622221e+01, -2.69893968e+01],
#        [ 1.00000000e+00, -1.64815779e+00,  2.71642411e+00,
#         -4.47709557e+00,  7.37895996e+00, -1.21616904e+01],
#        [ 1.00000000e+00, -9.92165497e-01,  9.84392374e-01,
#         -9.76680149e-01,  9.69028346e-01, -9.61436491e-01]])

# %%
from sklearn.metrics import r2_score
lin_reg2 = LinearRegression()
lin_reg2.fit(X_train_poly, y_train)
y_pred = lin_reg2.predict(X_test_poly)
score = r2_score(y_test, y_pred)
print('R2 score for Polynomial Regression:', score)
# Out:
# R2 score for Polynomial Regression: 0.8850670035812084

# %%
print('Coefficients:', lin_reg2.coef_)
# Out:
# Coefficients: [[ 0.          1.51241994  0.35822753 -0.03342609  0.0053491   0.00329384]]

# %%
print('Intercept:', lin_reg2.intercept_)
# Out:
# Intercept: [2.37258488]

# %%
plt.scatter(X_train, lin_reg2.predict(X_train_poly), color = 'r')
plt.scatter(X_train, y_train, color = 'g')

# %%
# Prediction of new data set
X_new = np.linspace(-3, 3, 200).reshape(200, 1)
X_new_poly = poly.transform(X_new)
X_new_poly
# Out:
# array([[   1.        ,   -3.        ,    9.        ,  -27.        ,
#           81.        , -243.        ],
#        [   1.        ,   -2.96984925,    8.82000455,  -26.19408385,
#           77.79248018, -231.03193862],
#        [   1.        ,   -2.93969849,    8.64182723,  -25.40436647,
#           74.68117781, -219.54014584],
#        ...,
#        [   1.        ,    2.93969849,    8.64182723,   25.40436647,
#           74.68117781,  219.54014584],
#        [   1.        ,    2.96984925,    8.82000455,   26.19408385,
#           77.79248018,  231.03193862],
#        [   1.        ,    3.        ,    9.        ,   27.        ,
#           81.        ,  243.        ]])

# %%
y_new = lin_reg2.predict(X_new_poly)
plt.plot(X_new, y_new, color = 'r', label = 'Predictions')
plt.plot(X_train, y_train, 'g.', label = 'Training data')
plt.plot(X_test, y_test, 'b.', label = 'Test data')
plt.xlabel('X dataset')
plt.ylabel('y dataset')
plt.legend()
plt.show()

# %% [markdown]
# Pipelining

# %%
from sklearn.pipeline import Pipeline

# %%
def poly_regression(degree):
    X_new = np.linspace(-3, 3, 200).reshape(200, 1)
    poly_features = PolynomialFeatures(degree = degree)
    lin_reg = LinearRegression()
    poly_regression = Pipeline([
        ('poly_features', poly_features),
        ('lin_reg', lin_reg)
    ])
    poly_regression.fit(X_train, y_train)
    y_pred_new = poly_regression.predict(X_new)
    # Plotting prediction line
    plt.plot(X_new, y_pred_new, label = 'Predictions', color = 'r')
    plt.plot(X_train, y_train, 'g.', label = 'Training data')
    plt.plot(X_test, y_test, 'b.', label = 'Test data')
    plt.legend(loc = "upper left")
    plt.xlabel('X dataset')
    plt.ylabel('y dataset')
    plt.show()

# %%
poly_regression(3)
